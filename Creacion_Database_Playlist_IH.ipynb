# %% [markdown]
# <a href="https://colab.research.google.com/github/diegomarlop/IH_Final_Project/blob/main/Creacion_Database_Playlist_IH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spotipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

# %%
#getting more tha 100 songs
#'Diego_Mtz','7ySOGN4GovIi4gtAgwud9W'

# %%
CLIENT_ID='6e9dc4a7a1814e978d0ca783aefdce21'
CLIENT_SECRET='901f86858e784fdeae15d4849870b786'

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,client_secret=CLIENT_SECRET))

# %%
####################33

# %%
prueba = sp.user_playlist_tracks('Diego_Mtz','7ySOGN4GovIi4gtAgwud9W')

# %%
prueba.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
p = prueba['items']

# %%
p2 =p[50]
print(p2.keys())
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
p2['track']['artists'][0]['uri']
# Out:
# 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'

# %%
v =sp.artist(artist_id='spotify:artist:27T030eWyCQRmDyuvr1kxY')

# %%
v['genres']
# Out:
# ['album rock',
#  'german hard rock',
#  'german metal',
#  'german rock',
#  'hard rock',
#  'metal',
#  'rock']

# %%
#solo acepta 50 solicitudes
#v = sp.artists(list_id_artist1)

# %%
#v.keys()

# %%
#playlist_rock['genre'] = f_50 + f_100 + f_150 + f_200 + f_250 + f_300 + f_350 + f_400 + f_450 + f_500 + f_550

# %%
#playlist_rock = playlist_rock.reset_index(drop=True)

# %%
#playlist_rock

# %%
############################################################playlist_rock###########################################################

# %%
def get_playlist_tracks(username,playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
play2 = get_playlist_tracks('Diego_Mtz','7ySOGN4GovIi4gtAgwud9W')

# %%
len(play2)
# Out:
# 543

# %%
list_album = []
list_artist = []
list_duration = []
list_rola = []
list_popularity = []
list_uri = []
list_id_artist = []
for cancion in play2:
  list_album.append(cancion['track']['album']['name'])
  list_artist.append(cancion['track']['artists'][0]['name'])
  list_duration.append(cancion['track']['duration_ms'])
  list_rola.append(cancion['track']['name'])
  list_popularity.append(cancion['track']['popularity'])
  list_uri.append(cancion['track']['uri'])
  list_id_artist.append(cancion['track']['artists'][0]['uri'])

# %%
#id artista
list_id_artist1 = list_id_artist[:50]
list_id_artist2 = list_id_artist[50:100]
list_id_artist3 = list_id_artist[100:150]
list_id_artist4 = list_id_artist[150:200]
list_id_artist5 = list_id_artist[200:250]
list_id_artist6 = list_id_artist[250:300]
list_id_artist7 = list_id_artist[300:350]
list_id_artist8 = list_id_artist[350:400]
list_id_artist9 = list_id_artist[400:450]
list_id_artist10 = list_id_artist[450:500]
list_id_artist11 = list_id_artist[500:]

# %%
#sacar genero de los artistas
list_genre1 = sp.artists(list_id_artist1)
list_genre2 = sp.artists(list_id_artist2)
list_genre3 = sp.artists(list_id_artist3)
list_genre4 = sp.artists(list_id_artist4)
list_genre5 = sp.artists(list_id_artist5)
list_genre6 = sp.artists(list_id_artist6)
list_genre7 = sp.artists(list_id_artist7)
list_genre8 = sp.artists(list_id_artist8)
list_genre9 = sp.artists(list_id_artist9)
list_genre10 = sp.artists(list_id_artist10)
list_genre11 = sp.artists(list_id_artist11)

# %%
f_50 = []
f_100 = []
f_150 = []
f_200 = []
f_250 = []
f_300 = []
f_350 = []
f_400 = []
f_450 = []
f_500 = []
for i in range(0,50):
  f_50.append(list_genre1['artists'][i]['genres'])
  f_100.append(list_genre2['artists'][i]['genres'])
  f_150.append(list_genre3['artists'][i]['genres'])
  f_200.append(list_genre4['artists'][i]['genres'])
  f_250.append(list_genre5['artists'][i]['genres'])
  f_300.append(list_genre6['artists'][i]['genres'])
  f_350.append(list_genre7['artists'][i]['genres'])
  f_400.append(list_genre8['artists'][i]['genres'])
  f_450.append(list_genre9['artists'][i]['genres'])
  f_500.append(list_genre10['artists'][i]['genres'])


f_550 = []
for i in range(0,43):
  #print(i)
  f_550.append(list_genre11['artists'][i]['genres'])

# %%
print(len(f_50))
print(len(f_100))
print(len(f_150))
print(len(f_200))
print(len(f_250))
print(len(f_300))
print(len(f_350))
print(len(f_400))
print(len(f_450))
print(len(f_500))
print(len(f_550))
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 43

# %%
#Tenemos que separar de 100 en 100 el total de las listas, ya que sp.auido_features() solo recibe un máximo de 100 id

# %%
#álbum
list_album1 = list_album[:100]
list_album2 = list_album[100:200]
list_album3 = list_album[200:300]
list_album4 = list_album[300:400]
list_album5 = list_album[400:500]
list_album6 = list_album[500:]

# %%
#verificamos que si esten todas las canciones (en este caso, yo sé que hay 533 canciones )
print(len(list_album1))
print(len(list_album2))
print(len(list_album3))
print(len(list_album4))
print(len(list_album5))
print(len(list_album6))
# Out:
# 100
# 100
# 100
# 100
# 100
# 43

# %%
#artista
list_artist1 = list_artist[:100]
list_artist2 = list_artist[100:200]
list_artist3 = list_artist[200:300]
list_artist4 = list_artist[300:400]
list_artist5 = list_artist[400:500]
list_artist6 = list_artist[500:]

# %%
print(len(list_artist1))
print(len(list_artist2))
print(len(list_artist3))
print(len(list_artist4))
print(len(list_artist5))
print(len(list_artist6))
# Out:
# 100
# 100
# 100
# 100
# 100
# 43

# %%
#rola
list_rola1 = list_rola[:100]
list_rola2 = list_rola[100:200]
list_rola3 = list_rola[200:300]
list_rola4 = list_rola[300:400]
list_rola5 = list_rola[400:500]
list_rola6 = list_rola[500:]

# %%
print(len(list_rola1))
print(len(list_rola2))
print(len(list_rola3))
print(len(list_rola4))
print(len(list_rola5))
print(len(list_rola6))
# Out:
# 100
# 100
# 100
# 100
# 100
# 43

# %%
#popularity
list_popularity1 = list_popularity[:100]
list_popularity2 = list_popularity[100:200]
list_popularity3 = list_popularity[200:300]
list_popularity4 = list_popularity[300:400]
list_popularity5 = list_popularity[400:500]
list_popularity6 = list_popularity[500:]

# %%
print(len(list_popularity1))
print(len(list_popularity2))
print(len(list_popularity3))
print(len(list_popularity4))
print(len(list_popularity5))
print(len(list_popularity6))
# Out:
# 100
# 100
# 100
# 100
# 100
# 43

# %%
#duration
list_duration1 = list_duration[:100]
list_duration2 = list_duration[100:200]
list_duration3 = list_duration[200:300]
list_duration4 = list_duration[300:400]
list_duration5 = list_duration[400:500]
list_duration6 = list_duration[500:]

# %%
print(len(list_duration1))
print(len(list_duration2))
print(len(list_duration3))
print(len(list_duration4))
print(len(list_duration5))
print(len(list_duration6))
# Out:
# 100
# 100
# 100
# 100
# 100
# 43

# %%
#uri/id
list_uri1 = list_uri[:100]
list_uri2 = list_uri[100:200]
list_uri3 = list_uri[200:300]
list_uri4 = list_uri[300:400]
list_uri5 = list_uri[400:500]
list_uri6 = list_uri[500:]

# %%
print(len(list_uri1))
print(len(list_uri2))
print(len(list_uri3))
print(len(list_uri4))
print(len(list_uri5))
print(len(list_uri6))
# Out:
# 100
# 100
# 100
# 100
# 100
# 43

# %%
#id artista
list_id_artist1 = list_id_artist[:50]
list_id_artist2 = list_id_artist[50:100]
list_id_artist3 = list_id_artist[100:150]
list_id_artist4 = list_id_artist[150:200]
list_id_artist5 = list_id_artist[200:250]
list_id_artist6 = list_id_artist[250:300]
list_id_artist7 = list_id_artist[300:350]
list_id_artist8 = list_id_artist[350:400]
list_id_artist9 = list_id_artist[400:450]
list_id_artist10 = list_id_artist[450:500]
list_id_artist11 = list_id_artist[500:]

# %%
#sacar los features de las canciones
list_feat1 = sp.audio_features(list_uri1)
list_feat2 = sp.audio_features(list_uri2)
list_feat3 = sp.audio_features(list_uri3)
list_feat4 = sp.audio_features(list_uri4)
list_feat5 = sp.audio_features(list_uri5)
list_feat6 = sp.audio_features(list_uri6)

# %%
#crear diccionario para guardar los features de las canciones 
dict_canciones_features1 = dict(
    name=list_rola1,
    artist = list_artist1,
    album = list_album1,
    popularity = list_popularity1,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat1:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features1.keys()):
      dict_canciones_features1[key].append(dict_audio_feautures[key])

# %%
print(len(dict_canciones_features1['name']))
print(len(dict_canciones_features1['artist']))
print(len(dict_canciones_features1['album']))
print(len(dict_canciones_features1['popularity']))
print(len(dict_canciones_features1['danceability']))
print(len(dict_canciones_features1['energy']))
print(len(dict_canciones_features1['key']))
print(len(dict_canciones_features1['loudness']))
print(len(dict_canciones_features1['speechiness']))
print(len(dict_canciones_features1['acousticness']))
print(len(dict_canciones_features1['instrumentalness']))
print(len(dict_canciones_features1['liveness']))
print(len(dict_canciones_features1['valence']))
print(len(dict_canciones_features1['tempo']))
print(len(dict_canciones_features1['duration_ms']))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
import pandas as pd 
data1 = pd.DataFrame(dict_canciones_features1)

# %%
data1
# Out:
#                        name                 artist  \
# 0           No One Like You              Scorpions
# 1           Highway to Hell                  AC/DC
# 2             Still Waiting                 Sum 41
# 3             The Hell Song                 Sum 41
# 4               Last Resort             Papa Roach
# ..                      ...                    ...
# 95            The Bad Touch        Bloodhound Gang
# 96     Old Time Rock & Roll              Bob Seger
# 97  Alone Again (Naturally)     Gilbert O'Sullivan
# 98                   Angels      Within Temptation
# 99        The Power Of Love  Huey Lewis & The News
#
#                                      album  popularity  danceability  energy  \
# 0                                 Blackout          64         0.505   0.631
# 1                          Highway to Hell          81         0.574   0.913
# 2                 Does This Look Infected?          62         0.431   0.950
# ...

# %%
dict_canciones_features2 = dict(
    name=list_rola2,
    artist = list_artist2,
    album = list_album2,
    popularity = list_popularity2,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat2:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features2.keys()):
      dict_canciones_features2[key].append(dict_audio_feautures[key])

# %%
print(len(dict_canciones_features2['name']))
print(len(dict_canciones_features2['artist']))
print(len(dict_canciones_features2['album']))
print(len(dict_canciones_features2['popularity']))
print(len(dict_canciones_features2['danceability']))
print(len(dict_canciones_features2['energy']))
print(len(dict_canciones_features2['key']))
print(len(dict_canciones_features2['loudness']))
print(len(dict_canciones_features2['speechiness']))
print(len(dict_canciones_features2['acousticness']))
print(len(dict_canciones_features2['instrumentalness']))
print(len(dict_canciones_features2['liveness']))
print(len(dict_canciones_features2['valence']))
print(len(dict_canciones_features2['tempo']))
print(len(dict_canciones_features2['duration_ms']))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
import pandas as pd 
data2 = pd.DataFrame(dict_canciones_features2)
data2
# Out:
#                             name                 artist  \
# 0                 Stuck With You  Huey Lewis & The News
# 1                   Back In Time  Huey Lewis & The News
# 2               Hip To Be Square  Huey Lewis & The News
# 3          Da Ya Think I'm Sexy?            Rod Stewart
# 4                         Maniac       Michael Sembello
# ..                           ...                    ...
# 95  Can't Get You out of My Head          Kylie Minogue
# 96            Original Prankster          The Offspring
# 97       Why Don't You Get A Job          The Offspring
# 98                          Down              blink-182
# 99    Stay Together For The Kids              blink-182
#
#                                                 album  popularity  \
# 0                                               Fore!          61
# 1              Greatest Hits: Huey Lewis And The News          53
# 2                                               Fore!          62
# ...

# %%
dict_canciones_features3 = dict(
    name=list_rola3,
    artist = list_artist3,
    album = list_album3,
    popularity = list_popularity3,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat3:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features3.keys()):
      dict_canciones_features3[key].append(dict_audio_feautures[key])

# %%
print(len(dict_canciones_features3['name']))
print(len(dict_canciones_features3['artist']))
print(len(dict_canciones_features3['album']))
print(len(dict_canciones_features3['popularity']))
print(len(dict_canciones_features3['danceability']))
print(len(dict_canciones_features3['energy']))
print(len(dict_canciones_features3['key']))
print(len(dict_canciones_features3['loudness']))
print(len(dict_canciones_features3['speechiness']))
print(len(dict_canciones_features3['acousticness']))
print(len(dict_canciones_features3['instrumentalness']))
print(len(dict_canciones_features3['liveness']))
print(len(dict_canciones_features3['valence']))
print(len(dict_canciones_features3['tempo']))
print(len(dict_canciones_features3['duration_ms']))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
import pandas as pd 
data3 = pd.DataFrame(dict_canciones_features3)
data3
# Out:
#                        name                 artist  \
# 0             The Rock Show              blink-182
# 1           Underclass Hero                 Sum 41
# 2        We're All To Blame                 Sum 41
# 3              Can't Repeat          The Offspring
# 4                  Hit That          The Offspring
# ..                      ...                    ...
# 95  Call Me Little Sunshine                  Ghost
# 96               The Middle        Jimmy Eat World
# 97     Animal I Have Become       Three Days Grace
# 98            Kill The King               Megadeth
# 99             Black Summer  Red Hot Chili Peppers
#
#                                album  popularity  danceability  energy  key  \
# 0     Take Off Your Pants And Jacket          68         0.410   0.959    9
# 1                    Underclass Hero          57         0.347   0.988    9
# 2                              Chuck          55         0.204   0.891    8
# ...

# %%
dict_canciones_features4 = dict(
    name=list_rola4,
    artist = list_artist4,
    album = list_album4,
    popularity = list_popularity4,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat4:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features4.keys()):
      dict_canciones_features4[key].append(dict_audio_feautures[key])

# %%
print(len(dict_canciones_features4['name']))
print(len(dict_canciones_features4['artist']))
print(len(dict_canciones_features4['album']))
print(len(dict_canciones_features4['popularity']))
print(len(dict_canciones_features4['danceability']))
print(len(dict_canciones_features4['energy']))
print(len(dict_canciones_features4['key']))
print(len(dict_canciones_features4['loudness']))
print(len(dict_canciones_features4['speechiness']))
print(len(dict_canciones_features4['acousticness']))
print(len(dict_canciones_features4['instrumentalness']))
print(len(dict_canciones_features4['liveness']))
print(len(dict_canciones_features4['valence']))
print(len(dict_canciones_features4['tempo']))
print(len(dict_canciones_features4['duration_ms']))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
import pandas as pd 
data4 = pd.DataFrame(dict_canciones_features4)
data4
# Out:
#                                  name                    artist  \
# 0                              Poison              Alice Cooper
# 1       Too Much, Too Young, Too Fast                 Airbourne
# 2                         Live To Win              Paul Stanley
# 3                     All Summer Long                  Kid Rock
# 4                       Until the End         Avenged Sevenfold
# ..                                ...                       ...
# 95     Everything Is Average Nowadays             Kaiser Chiefs
# 96                     Gives You Hell  The All-American Rejects
# 97  Everyday I Love You Less and Less             Kaiser Chiefs
# 98                  Lights And Sounds                Yellowcard
# 99               Everybody's Changing                     Keane
#
#                               album  popularity  danceability  energy  key  \
# 0                             Trash          70         0.280   0.908    2
# ...

# %%
dict_canciones_features5 = dict(
    name=list_rola5,
    artist = list_artist5,
    album = list_album5,
    popularity = list_popularity5,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat5:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features5.keys()):
      dict_canciones_features5[key].append(dict_audio_feautures[key])

# %%
print(len(dict_canciones_features4['name']))
print(len(dict_canciones_features4['artist']))
print(len(dict_canciones_features4['album']))
print(len(dict_canciones_features4['popularity']))
print(len(dict_canciones_features4['danceability']))
print(len(dict_canciones_features4['energy']))
print(len(dict_canciones_features4['key']))
print(len(dict_canciones_features4['loudness']))
print(len(dict_canciones_features4['speechiness']))
print(len(dict_canciones_features4['acousticness']))
print(len(dict_canciones_features4['instrumentalness']))
print(len(dict_canciones_features4['liveness']))
print(len(dict_canciones_features4['valence']))
print(len(dict_canciones_features4['tempo']))
print(len(dict_canciones_features4['duration_ms']))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
import pandas as pd 
data5 = pd.DataFrame(dict_canciones_features5)
data5
# Out:
#                             name               artist  \
# 0        The Writing on the Wall          Iron Maiden
# 1   Los Malaventurados No Lloran                PXNDX
# 2                      The River       Good Charlotte
# 3             Somewhere I Belong          Linkin Park
# 4                          Dead!  My Chemical Romance
# ..                           ...                  ...
# 95                  We Die Young      Alice In Chains
# 96                  Another Life  Motionless In White
# 97                      Werewolf  Motionless In White
# 98                Brand New Numb  Motionless In White
# 99                          Soft  Motionless In White
#
#                            album  popularity  danceability  energy  key  \
# 0        The Writing On The Wall          45         0.402   0.912    2
# 1           Amantes Sunt Amentes          69         0.488   0.897    8
# 2           Good Morning Revival          57         0.439   0.945    1
# ...

# %%
dict_canciones_features6 = dict(
    name=list_rola6,
    artist = list_artist6,
    album = list_album6,
    popularity = list_popularity6,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat6:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features6.keys()):
      dict_canciones_features6[key].append(dict_audio_feautures[key])

# %%
print(len(dict_canciones_features6['name']))
print(len(dict_canciones_features6['artist']))
print(len(dict_canciones_features6['album']))
print(len(dict_canciones_features6['popularity']))
print(len(dict_canciones_features6['danceability']))
print(len(dict_canciones_features6['energy']))
print(len(dict_canciones_features6['key']))
print(len(dict_canciones_features6['loudness']))
print(len(dict_canciones_features6['speechiness']))
print(len(dict_canciones_features6['acousticness']))
print(len(dict_canciones_features6['instrumentalness']))
print(len(dict_canciones_features6['liveness']))
print(len(dict_canciones_features6['valence']))
print(len(dict_canciones_features6['tempo']))
print(len(dict_canciones_features6['duration_ms']))
# Out:
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43
# 43

# %%
data6 = pd.DataFrame(dict_canciones_features6)
data6
# Out:
#                             name                   artist  \
# 0             Thoughts & Prayers      Motionless In White
# 1                         Movies           Alien Ant Farm
# 2                   Shadow Moses     Bring Me The Horizon
# 3                         Throne     Bring Me The Horizon
# 4   Kingslayer (feat. BABYMETAL)     Bring Me The Horizon
# 5                         MANTRA     Bring Me The Horizon
# 6              Voices In My Head       Falling In Reverse
# 7                    in the dark     Bring Me The Horizon
# 8              One For the Money          Escape the Fate
# 9                      ZOMBIFIED       Falling In Reverse
# 10         The Drug In Me Is You       Falling In Reverse
# 11             I'm Not A Vampire       Falling In Reverse
# 12            Bulls In The Bronx          Pierce The Veil
# 13                    The Legacy        Black Veil Brides
# 14               Knives and Pens        Black Veil Brides
# ...

# %%
playlist_rock= pd.concat([data1,data2,data3,data4,data5,data6],axis=0)

# %%
playlist_rock.reset_index(drop=True)
# Out:
#                       name               artist  \
# 0          No One Like You            Scorpions
# 1          Highway to Hell                AC/DC
# 2            Still Waiting               Sum 41
# 3            The Hell Song               Sum 41
# 4              Last Resort           Papa Roach
# ..                     ...                  ...
# 538  Cryin' Like A Bitch!!             Godsmack
# 539   Falling Away from Me                 Korn
# 540         Bad Girlfriend  Theory of a Deadman
# 541              Mudshovel               Staind
# 542                 Colors            Crossfade
#
#                                    album  popularity  danceability  energy  \
# 0                               Blackout          64         0.505   0.631
# 1                        Highway to Hell          81         0.574   0.913
# 2               Does This Look Infected?          62         0.431   0.950
# 3               Does This Look Infected?          56         0.359   0.935
# ...

# %%
playlist_rock['genre'] = f_50 + f_100 + f_150 + f_200 + f_250 + f_300 + f_350 + f_400 + f_450 + f_500 + f_550

# %%
playlist_rock = playlist_rock.reset_index(drop=True)

# %%
playlist_rock
# Out:
#                       name               artist  \
# 0          No One Like You            Scorpions
# 1          Highway to Hell                AC/DC
# 2            Still Waiting               Sum 41
# 3            The Hell Song               Sum 41
# 4              Last Resort           Papa Roach
# ..                     ...                  ...
# 538  Cryin' Like A Bitch!!             Godsmack
# 539   Falling Away from Me                 Korn
# 540         Bad Girlfriend  Theory of a Deadman
# 541              Mudshovel               Staind
# 542                 Colors            Crossfade
#
#                                    album  popularity  danceability  energy  \
# 0                               Blackout          64         0.505   0.631
# 1                        Highway to Hell          81         0.574   0.913
# 2               Does This Look Infected?          62         0.431   0.950
# 3               Does This Look Infected?          56         0.359   0.935
# ...

# %%
playlist_rock.to_excel('playlistrock.xlsx')

# %%
###########################################################largest roock playlist#################################################################

# %%
CLIENT_ID='6e9dc4a7a1814e978d0ca783aefdce21'
CLIENT_SECRET='901f86858e784fdeae15d4849870b786'

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,client_secret=CLIENT_SECRET))

# %%
def get_playlist_tracks(username,playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
play3 = get_playlist_tracks('Diego_Mtz','5xEIQ2u3ZzG5gt0Cg7uDrj')

# %%
len(play3)
# Out:
# 1349

# %%
list_album = []
list_artist = []
list_duration = []
list_rola = []
list_popularity = []
list_uri = []
list_id_artist = []
for cancion in play3:
  list_album.append(cancion['track']['album']['name'])
  list_artist.append(cancion['track']['artists'][0]['name'])
  list_duration.append(cancion['track']['duration_ms'])
  list_rola.append(cancion['track']['name'])
  list_popularity.append(cancion['track']['popularity'])
  list_uri.append(cancion['track']['uri'])
  list_id_artist.append(cancion['track']['artists'][0]['uri'])

# %%
#id artista
list_id_artist1 = list_id_artist[:50]
list_id_artist2 = list_id_artist[50:100]
list_id_artist3 = list_id_artist[100:150]
list_id_artist4 = list_id_artist[150:200]
list_id_artist5 = list_id_artist[200:250]
list_id_artist6 = list_id_artist[250:300]
list_id_artist7 = list_id_artist[300:350]
list_id_artist8 = list_id_artist[350:400]
list_id_artist9 = list_id_artist[400:450]
list_id_artist10 = list_id_artist[450:500]
list_id_artist11 = list_id_artist[500:550]
list_id_artist12 = list_id_artist[550:600]
list_id_artist13 = list_id_artist[600:650]
list_id_artist14 = list_id_artist[650:700]
list_id_artist15 = list_id_artist[700:750]
list_id_artist16 = list_id_artist[750:800]
list_id_artist17 = list_id_artist[800:850]
list_id_artist18 = list_id_artist[850:900]
list_id_artist19 = list_id_artist[900:950]
list_id_artist20 = list_id_artist[950:1000]
list_id_artist21 = list_id_artist[1000:1050]
list_id_artist22 = list_id_artist[1050:1100]
list_id_artist23 = list_id_artist[1100:1150]
list_id_artist24 = list_id_artist[1150:1200]
list_id_artist25 = list_id_artist[1200:1250]
list_id_artist26 = list_id_artist[1250:1300]
list_id_artist27 = list_id_artist[1300:]

# %%
#sacar genero de los artistas
list_genre1 = sp.artists(list_id_artist1)
list_genre2 = sp.artists(list_id_artist2)
list_genre3 = sp.artists(list_id_artist3)
list_genre4 = sp.artists(list_id_artist4)
list_genre5 = sp.artists(list_id_artist5)
list_genre6 = sp.artists(list_id_artist6)
list_genre7 = sp.artists(list_id_artist7)
list_genre8 = sp.artists(list_id_artist8)
list_genre9 = sp.artists(list_id_artist9)
list_genre10 = sp.artists(list_id_artist10)
list_genre11 = sp.artists(list_id_artist11)
list_genre12 = sp.artists(list_id_artist12)
list_genre13 = sp.artists(list_id_artist13)
list_genre14 = sp.artists(list_id_artist14)
list_genre15 = sp.artists(list_id_artist15)
list_genre16 = sp.artists(list_id_artist16)
list_genre17 = sp.artists(list_id_artist17)
list_genre18 = sp.artists(list_id_artist18)
list_genre19 = sp.artists(list_id_artist19)
list_genre20 = sp.artists(list_id_artist20)
list_genre21 = sp.artists(list_id_artist21)
list_genre22 = sp.artists(list_id_artist22)
list_genre23 = sp.artists(list_id_artist23)
list_genre24 = sp.artists(list_id_artist24)
list_genre25 = sp.artists(list_id_artist25)
list_genre26 = sp.artists(list_id_artist26)
list_genre27 = sp.artists(list_id_artist27)

# %%
f_50 = []
f_100 = []
f_150 = []
f_200 = []
f_250 = []
f_300 = []
f_350 = []
f_400 = []
f_450 = []
f_500 = []
f_550 = []
f_600 = []
f_650 = []
f_700 = []
f_750 = []
f_800 = []
f_850 = []
f_900 = []
f_950 = []
f_1000 = []
f_1050 = []
f_1100 = []
f_1150 = []
f_1200 = []
f_1250 = []
f_1300 = []
for i in range(0,50):
  f_50.append(list_genre1['artists'][i]['genres'])
  f_100.append(list_genre2['artists'][i]['genres'])
  f_150.append(list_genre3['artists'][i]['genres'])
  f_200.append(list_genre4['artists'][i]['genres'])
  f_250.append(list_genre5['artists'][i]['genres'])
  f_300.append(list_genre6['artists'][i]['genres'])
  f_350.append(list_genre7['artists'][i]['genres'])
  f_400.append(list_genre8['artists'][i]['genres'])
  f_450.append(list_genre9['artists'][i]['genres'])
  f_500.append(list_genre10['artists'][i]['genres'])
  f_550.append(list_genre11['artists'][i]['genres'])
  f_600.append(list_genre12['artists'][i]['genres'])
  f_650.append(list_genre13['artists'][i]['genres'])
  f_700.append(list_genre14['artists'][i]['genres'])
  f_750.append(list_genre15['artists'][i]['genres'])
  f_800.append(list_genre16['artists'][i]['genres'])
  f_850.append(list_genre17['artists'][i]['genres'])
  f_900.append(list_genre18['artists'][i]['genres'])
  f_950.append(list_genre19['artists'][i]['genres'])
  f_1000.append(list_genre20['artists'][i]['genres'])
  f_1050.append(list_genre21['artists'][i]['genres'])
  f_1100.append(list_genre22['artists'][i]['genres'])
  f_1150.append(list_genre23['artists'][i]['genres'])
  f_1200.append(list_genre24['artists'][i]['genres'])
  f_1250.append(list_genre25['artists'][i]['genres'])
  f_1300.append(list_genre26['artists'][i]['genres'])

# %%
f_1350 = []
for i in range(0,49):
  #print(i)
  f_1350.append(list_genre27['artists'][i]['genres'])

# %%
print(len(f_50))
print(len(f_100))
print(len(f_150))
print(len(f_200))
print(len(f_250))
print(len(f_300))
print(len(f_350))
print(len(f_400))
print(len(f_450))
print(len(f_500))
print(len(f_550))
print(len(f_600))
print(len(f_650))
print(len(f_700))
print(len(f_750))
print(len(f_800))
print(len(f_850))
print(len(f_900))
print(len(f_950))
print(len(f_1000))
print(len(f_1050))
print(len(f_1100))
print(len(f_1150))
print(len(f_1200))
print(len(f_1250))
print(len(f_1300))
print(len(f_1350))
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 49

# %%
len(list_album)
# Out:
# 1349

# %%
#álbum
list_album1 = list_album[:100]
list_album2 = list_album[100:200]
list_album3 = list_album[200:300]
list_album4 = list_album[300:400]
list_album5 = list_album[400:500]
list_album6 = list_album[500:600]
list_album7 = list_album[600:700]
list_album8 = list_album[700:800]
list_album9 = list_album[800:900]
list_album10 = list_album[900:1000]
list_album11 = list_album[1000:1100]
list_album12 = list_album[1100:1200]
list_album13 = list_album[1200:1300]
list_album14 = list_album[1300:]

# %%
#artist
list_artist1 = list_artist[:100]
list_artist2 = list_artist[100:200]
list_artist3 = list_artist[200:300]
list_artist4 = list_artist[300:400]
list_artist5 = list_artist[400:500]
list_artist6 = list_artist[500:600]
list_artist7 = list_artist[600:700]
list_artist8 = list_artist[700:800]
list_artist9 = list_artist[800:900]
list_artist10 = list_artist[900:1000]
list_artist11 = list_artist[1000:1100]
list_artist12 = list_artist[1100:1200]
list_artist13 = list_artist[1200:1300]
list_artist14 = list_artist[1300:]

# %%
#rola
list_rola1 = list_rola[:100]
list_rola2 = list_rola[100:200]
list_rola3 = list_rola[200:300]
list_rola4 = list_rola[300:400]
list_rola5 = list_rola[400:500]
list_rola6 = list_rola[500:600]
list_rola7 = list_rola[600:700]
list_rola8 = list_rola[700:800]
list_rola9 = list_rola[800:900]
list_rola10 = list_rola[900:1000]
list_rola11 = list_rola[1000:1100]
list_rola12 = list_rola[1100:1200]
list_rola13 = list_rola[1200:1300]
list_rola14 = list_rola[1300:]

# %%
#popularity
list_popularity1 = list_popularity[:100]
list_popularity2 = list_popularity[100:200]
list_popularity3 = list_popularity[200:300]
list_popularity4 = list_popularity[300:400]
list_popularity5 = list_popularity[400:500]
list_popularity6 = list_popularity[500:600]
list_popularity7 = list_popularity[600:700]
list_popularity8 = list_popularity[700:800]
list_popularity9 = list_popularity[800:900]
list_popularity10 = list_popularity[900:1000]
list_popularity11 = list_popularity[1000:1100]
list_popularity12 = list_popularity[1100:1200]
list_popularity13 = list_popularity[1200:1300]
list_popularity14 = list_popularity[1300:]

# %%
#uri
list_uri7 = list_uri[:100]
list_uri8 = list_uri[100:200]
list_uri9 = list_uri[200:300]
list_uri10 = list_uri[300:400]
list_uri11 = list_uri[400:500]
list_uri12 = list_uri[500:600]
list_uri13 = list_uri[600:700]
list_uri14 = list_uri[700:800]
list_uri15 = list_uri[800:900]
list_uri16 = list_uri[900:1000]
list_uri17 = list_uri[1000:1100]
list_uri18 = list_uri[1100:1200]
list_uri19 = list_uri[1200:1300]
list_uri20 = list_uri[1300:]

# %%
#features
list_feat1 = sp.audio_features(list_uri7)
list_feat2 = sp.audio_features(list_uri8)
list_feat3 = sp.audio_features(list_uri9)
list_feat4 = sp.audio_features(list_uri10)
list_feat5 = sp.audio_features(list_uri11)
list_feat6 = sp.audio_features(list_uri12)
list_feat7 = sp.audio_features(list_uri13)
list_feat8 = sp.audio_features(list_uri14)
list_feat9 = sp.audio_features(list_uri15)
list_feat10 = sp.audio_features(list_uri16)
list_feat11 = sp.audio_features(list_uri17)
list_feat12 = sp.audio_features(list_uri18)
list_feat13 = sp.audio_features(list_uri19)
list_feat14 = sp.audio_features(list_uri20)

# %%
dict_canciones_features1 = dict(
    name=list_rola1,
    artist = list_artist1,
    album = list_album1,
    popularity = list_popularity1,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat1:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features1.keys()):
      dict_canciones_features1[key].append(dict_audio_feautures[key])

# %%
import pandas as pd 
data1 = pd.DataFrame(dict_canciones_features1)
data1
# Out:
#                     name                 artist  \
# 0       Freak On a Leash                   Korn
# 1   Falling Away from Me                   Korn
# 2          Coming Undone                   Korn
# 3     Twisted Transistor                   Korn
# 4            Break Stuff            Limp Bizkit
# ..                   ...                    ...
# 95             Otherside  Red Hot Chili Peppers
# 96      Yellow Ledbetter              Pearl Jam
# 97          Learn to Fly           Foo Fighters
# 98           Scar Tissue  Red Hot Chili Peppers
# 99            Far Behind              Candlebox
#
#                                album  popularity  danceability  energy  key  \
# 0                  Follow The Leader          73         0.353   0.898    2
# 1                             Issues          70         0.468   0.769    4
# 2          See You On the Other Side           1         0.687   0.677    2
# 3          See You On the Other Side           0         0.580   0.983    5
# ...

# %%
dict_canciones_features2 = dict(
    name=list_rola2,
    artist = list_artist2,
    album = list_album2,
    popularity = list_popularity2,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat2:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features2.keys()):
      dict_canciones_features2[key].append(dict_audio_feautures[key])

# %%
data2 = pd.DataFrame(dict_canciones_features2)
data2
# Out:
#                        name                 artist  \
# 0                   No Rain            Blind Melon
# 1    1979 - Remastered 2012  The Smashing Pumpkins
# 2                Cumbersome       Seven Mary Three
# 3     If You Could Only See                  Tonic
# 4              Santa Monica              Everclear
# ..                      ...                    ...
# 95  Symphony Of Destruction               Megadeth
# 96                   Mother                 Danzig
# 97            Wall of Shame       Course Of Nature
# 98  The People That We Love                   Bush
# 99            Hunger Strike      Temple Of The Dog
#
#                                                 album  popularity  \
# 0                                         Blind Melon          73
# 1   Mellon Collie And The Infinite Sadness (Deluxe...          74
# 2                                   American Standard          63
# 3                                        Lemon Parade          64
# ...

# %%
dict_canciones_features3 = dict(
    name=list_rola3,
    artist = list_artist3,
    album = list_album3,
    popularity = list_popularity3,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat3:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features3.keys()):
      dict_canciones_features3[key].append(dict_audio_feautures[key])

# %%
data3 = pd.DataFrame(dict_canciones_features3)
data3
# Out:
#                                name                 artist  \
# 0   One Little Victory - 2013 Remix                   Rush
# 1                    This Means War      Avenged Sevenfold
# 2                     The Pretender           Foo Fighters
# 3                         Afterlife      Avenged Sevenfold
# 4                       Self Esteem          The Offspring
# ..                              ...                    ...
# 95                        Aeroplane  Red Hot Chili Peppers
# 96                   Take a Picture                 Filter
# 97                          The Way               Fastball
# 98                         Fly Away          Lenny Kravitz
# 99                   American Woman          Lenny Kravitz
#
#                                 album  popularity  danceability  energy  key  \
# 0           Vapor Trails (2013 Remix)          33         0.493   0.938    4
# 1                    Hail to the King          60         0.614   0.914    7
# ...

# %%
dict_canciones_features4 = dict(
    name=list_rola4,
    artist = list_artist4,
    album = list_album4,
    popularity = list_popularity4,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat4:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features4.keys()):
      dict_canciones_features4[key].append(dict_audio_feautures[key])

# %%
data4 = pd.DataFrame(dict_canciones_features4)
data4
# Out:
#                                                  name  \
# 0                                               Crazy
# 1                                            One Week
# 2                                          Run-Around
# 3                                                 3AM
# 4                                               Drive
# ..                                                ...
# 95                                        All For You
# 96                             Breakfast At Tiffany's
# 97  Counting Blue Cars (Tell Me Your Thoughts On God)
# 98                                          Glycerine
# 99                          The Impression That I Get
#
#                          artist                             album  popularity  \
# 0                     Aerosmith                        Get A Grip          71
# 1              Barenaked Ladies  Stunt (20th Anniversary Edition)          66
# 2                Blues Traveler                              Four          62
# ...

# %%
dict_canciones_features5 = dict(
    name=list_rola5,
    artist = list_artist5,
    album = list_album5,
    popularity = list_popularity5,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat5:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features5.keys()):
      dict_canciones_features5[key].append(dict_audio_feautures[key])

# %%
data5 = pd.DataFrame(dict_canciones_features5)
data5
# Out:
#                                                  name            artist  \
# 0                                   Life Is A Highway      Tom Cochrane
# 1                                     Misery Business          Paramore
# 2                                         Just A Girl          No Doubt
# 3                                   Since U Been Gone    Kelly Clarkson
# 4                                        Ain't It Fun          Paramore
# ..                                                ...               ...
# 95                                      Twice As Hard  The Black Crowes
# 96  Country Boy (feat. George Jones & Charlie Dani...       Aaron Lewis
# 97                                   It's Not My Time      3 Doors Down
# 98                                     Black Hole Sun       Soundgarden
# 99                                            Cochise        Audioslave
#
#                             album  popularity  danceability  energy  key  \
# ...

# %%
dict_canciones_features6 = dict(
    name=list_rola6,
    artist = list_artist6,
    album = list_album6,
    popularity = list_popularity6,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat6:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features6.keys()):
      dict_canciones_features6[key].append(dict_audio_feautures[key])

# %%
data6 = pd.DataFrame(dict_canciones_features6)
data6
# Out:
#                         name                      artist  \
# 0                       Riot            Three Days Grace
# 1                  Face Down  The Red Jumpsuit Apparatus
# 2         Jumper - 1998 Edit             Third Eye Blind
# 3              When I'm Gone                3 Doors Down
# 4                Angels Fall           Breaking Benjamin
# ..                       ...                         ...
# 95                    Animal                      Mudmen
# 96  Getting Away With Murder                  Papa Roach
# 97                  Lay Down                   Priestess
# 98         The Seeker - Edit                     The Who
# 99             Pride and Joy          Stevie Ray Vaughan
#
#                                                 album  popularity  \
# 0                                               One-X          68
# 1                                   Don't You Fake It          72
# 2                                     Third Eye Blind          63
# ...

# %%
dict_canciones_features7 = dict(
    name=list_rola7,
    artist = list_artist7,
    album = list_album7,
    popularity = list_popularity7,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat7:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features7.keys()):
      dict_canciones_features7[key].append(dict_audio_feautures[key])

# %%
data7 = pd.DataFrame(dict_canciones_features7)
data7
# Out:
#                                                  name  \
# 0                                  Knights of Cydonia
# 1   The Number Of The Beast - 1998 Remastered Version
# 2                                            Float On
# 3                                            The Kill
# 4                 Trippin' on a Hole in a Paper Heart
# ..                                                ...
# 95                                        Lay It Down
# 96                                    Round and Round
# 97                                      Far From Home
# 98                                  Well Enough Alone
# 99                                      World so Cold
#
#                      artist  \
# 0                      Muse
# 1               Iron Maiden
# 2              Modest Mouse
# 3    Thirty Seconds To Mars
# 4       Stone Temple Pilots
# ..                      ...
# 95                     Ratt
# 96                     Ratt
# 97  Five Finger Death Punch
# ...

# %%
dict_canciones_features8 = dict(
    name=list_rola8,
    artist = list_artist8,
    album = list_album8,
    popularity = list_popularity8,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat8:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features8.keys()):
      dict_canciones_features8[key].append(dict_audio_feautures[key])

# %%
data8 = pd.DataFrame(dict_canciones_features8)
data8
# Out:
#                                 name               artist  \
# 0                    Youth Gone Wild             Skid Row
# 1                     Same Direction           Hoobastank
# 2                 Wish You Were Here           Pink Floyd
# 3    Money - 2011 Remastered Version           Pink Floyd
# 4   Another Brick in the Wall, Pt. 2           Pink Floyd
# ..                               ...                  ...
# 95                       Self Esteem        The Offspring
# 96                   Come As You Are              Nirvana
# 97                             Plush  Stone Temple Pilots
# 98                          Santeria              Sublime
# 99                 Lightning Crashes                 Live
#
#                                                 album  popularity  \
# 0                                            Skid Row          61
# 1                                          The Reason           0
# 2                                  Wish You Were Here          73
# ...

# %%
dict_canciones_features9 = dict(
    name=list_rola9,
    artist = list_artist9,
    album = list_album9,
    popularity = list_popularity9,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat9:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features9.keys()):
      dict_canciones_features9[key].append(dict_audio_feautures[key])

# %%
data9 = pd.DataFrame(dict_canciones_features9)
data9
# Out:
#                                  name                        artist  \
# 0                        The Distance                          CAKE
# 1                    Who's Crying Now                       Journey
# 2                          Rebel Yell                    Billy Idol
# 3                        Bad Medicine                      Bon Jovi
# 4   You Spin Me Round (Like a Record)                 Dead Or Alive
# ..                                ...                           ...
# 95               Carry on Wayward Son                        Kansas
# 96              Sunshine Of Your Love                         Cream
# 97                      Can't You See      The Marshall Tucker Band
# 98                        Who Are You                       The Who
# 99                    Bad Moon Rising  Creedence Clearwater Revival
#
#                                      album  popularity  danceability  energy  \
# ...

# %%
dict_canciones_features10 = dict(
    name=list_rola10,
    artist = list_artist10,
    album = list_album10,
    popularity = list_popularity10,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat10:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features10.keys()):
      dict_canciones_features10[key].append(dict_audio_feautures[key])

# %%
data10 = pd.DataFrame(dict_canciones_features10)
data10
# Out:
#                                 name              artist  \
# 0                   Comfortably Numb          Pink Floyd
# 1                      All Right Now                Free
# 2                           Touch Me           The Doors
# 3       Beast Of Burden - Remastered  The Rolling Stones
# 4                         My Sharona           The Knack
# ..                               ...                 ...
# 95                     Made Of Glass               Trapt
# 96       You Don't Know How It Feels           Tom Petty
# 97                             Ænema                TOOL
# 98                    Hate by Design   Killswitch Engage
# 99  Looking Down the Barrel of Today           Hatebreed
#
#                               album  popularity  danceability  energy  key  \
# 0                          The Wall          71         0.472   0.366   11
# 1   Fire And Water (Deluxe Edition)           0         0.766   0.446    2
# ...

# %%
dict_canciones_features11 = dict(
    name=list_rola11,
    artist = list_artist11,
    album = list_album11,
    popularity = list_popularity11,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat11:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features11.keys()):
      dict_canciones_features11[key].append(dict_audio_feautures[key])

# %%
data11 = pd.DataFrame(dict_canciones_features11)
data11
# Out:
#                                           name               artist  \
# 0                               Lakini's Juice                 Live
# 1          In My Time of Dying - 1990 Remaster         Led Zeppelin
# 2                                     Funk #49           James Gang
# 3                                      Sunburn                 Fuel
# 4                                 Hate My Life  Theory of a Deadman
# ..                                         ...                  ...
# 95                   Let My Love Open The Door       Pete Townshend
# 96  The Reflex - Single Version; 2010 Remaster          Duran Duran
# 97                         Welcome to Paradise            Green Day
# 98                                        Laid                James
# 99                               Mother Mother         Tracy Bonham
#
#                                           album  popularity  danceability  \
# 0                                Secret Samadhi          50         0.375
# ...

# %%
dict_canciones_features12 = dict(
    name=list_rola12,
    artist = list_artist12,
    album = list_album12,
    popularity = list_popularity12,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat12:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features12.keys()):
      dict_canciones_features12[key].append(dict_audio_feautures[key])

# %%
data12 = pd.DataFrame(dict_canciones_features12)
data12
# Out:
#                         name                           artist  \
# 0   Into The Great Wide Open  Tom Petty and the Heartbreakers
# 1      Bang the Drum All Day                    Todd Rundgren
# 2                    Save Me                        Shinedown
# 3            Breaking Inside                        Shinedown
# 4               What a Shame                        Shinedown
# ..                       ...                              ...
# 95              Here to Stay                             Korn
# 96                 Right Now                             Korn
# 97      Wherever You Will Go                      The Calling
# 98            There She Goes                         The La's
# 99            I'm Just a Kid                      Simple Plan
#
#                                                 album  popularity  \
# 0                            Into The Great Wide Open          54
# 1             The Ever Popular Tortured Artist Effect          49
# ...

# %%
dict_canciones_features13 = dict(
    name=list_rola13,
    artist = list_artist13,
    album = list_album13,
    popularity = list_popularity13,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat13:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features13.keys()):
      dict_canciones_features13[key].append(dict_audio_feautures[key])

# %%
data13 = pd.DataFrame(dict_canciones_features13)
data13
# Out:
#                     name             artist  \
# 0                Perfect        Simple Plan
# 1      Kick In The Teeth         Papa Roach
# 2           Jet Airliner  Steve Miller Band
# 3   No More Mr. Nice Guy       Alice Cooper
# 4              Spaceship     Puddle Of Mudd
# ..                   ...                ...
# 95                  Time         Pink Floyd
# 96              Nutshell    Alice In Chains
# 97         Your Decision    Alice In Chains
# 98     Shadow on the Sun         Audioslave
# 99           Predictable     Good Charlotte
#
#                                                 album  popularity  \
# 0   No Pads, No Helmets...Just Balls (15th Anniver...          66
# 1   Time For Annihilation: On the Record & On the ...          47
# 2                                      Book Of Dreams          53
# 3              Billion Dollar Babies (Deluxe Reissue)          57
# 4   Vol. 4: Songs In The Key Of Love & Hate (Delux...          43
# ...

# %%
dict_canciones_features14 = dict(
    name=list_rola14,
    artist = list_artist14,
    album = list_album14,
    popularity = list_popularity14,
    danceability = [],
    energy = [],
    key = [],
    loudness = [],
    mode = [],
    speechiness = [],
    acousticness = [],
    instrumentalness = [],
    liveness = [],
    valence = [],
    tempo = [],
    duration_ms = []

)

# %%
for dict_audio_feautures in list_feat14:
  for key in dict_audio_feautures:
    if key in list(dict_canciones_features14.keys()):
      dict_canciones_features14[key].append(dict_audio_feautures[key])

# %%
data14 = pd.DataFrame(dict_canciones_features14)
data14
# Out:
#                                    name                   artist  \
# 0                   Do You Call My Name                       Ra
# 1                     Stand Up (For It)       Dave Matthews Band
# 2                            Kryptonite             3 Doors Down
# 3            Rollin' (Air Raid Vehicle)              Limp Bizkit
# 4                              Papercut              Linkin Park
# 5                         Meant to Live               Switchfoot
# 6                        Do What You Do                 Mudvayne
# 7                               The Pot                     TOOL
# 8                      Moving in Stereo                 The Cars
# 9                             Kiss This               The Struts
# 10     Fool in the Rain - 1990 Remaster             Led Zeppelin
# 11                               Yellow                 Coldplay
# 12                         Subdivisions                     Rush
# ...

# %%
largest_playlist = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12,data13,data14],axis=0)

# %%
largest_playlist = largest_playlist.reset_index(drop=True)

# %%
largest_playlist
# Out:
#                           name               artist  \
# 0             Freak On a Leash                 Korn
# 1         Falling Away from Me                 Korn
# 2                Coming Undone                 Korn
# 3           Twisted Transistor                 Korn
# 4                  Break Stuff          Limp Bizkit
# ...                        ...                  ...
# 1344         Hey There Delilah      Plain White T's
# 1345  I'm Not Okay (I Promise)  My Chemical Romance
# 1346  Peace Sells - Remastered             Megadeth
# 1347                 Cold Shot   Stevie Ray Vaughan
# 1348             Coming Undone              Tantric
#
#                                                   album  popularity  \
# 0                                     Follow The Leader          73
# 1                                                Issues          70
# 2                             See You On the Other Side           1
# ...

# %%
largest_playlist['genre'] = f_50 + f_100 + f_150 + f_200 + f_250 + f_300 + f_350 + f_400 + f_450 + f_500 + f_550 + f_600 + f_650 + f_700 + f_750 + f_800 + f_850 + f_900 + f_950 + f_100 + f_1050 + f_1100 + f_1150 + f_1200 + f_1250 + f_1300 + f_1350

# %%
largest_playlist = largest_playlist.reset_index(drop=True)

# %%
largest_playlist
# Out:
#                           name               artist  \
# 0             Freak On a Leash                 Korn
# 1         Falling Away from Me                 Korn
# 2                Coming Undone                 Korn
# 3           Twisted Transistor                 Korn
# 4                  Break Stuff          Limp Bizkit
# ...                        ...                  ...
# 1344         Hey There Delilah      Plain White T's
# 1345  I'm Not Okay (I Promise)  My Chemical Romance
# 1346  Peace Sells - Remastered             Megadeth
# 1347                 Cold Shot   Stevie Ray Vaughan
# 1348             Coming Undone              Tantric
#
#                                                   album  popularity  \
# 0                                     Follow The Leader          73
# 1                                                Issues          70
# 2                             See You On the Other Side           1
# ...

# %%
####

# %%
largest_playlist.to_excel('largestplaylist.xlsx')

# %%
#concat the two playlists
data = pd.concat([playlist_rock,largest_playlist],axis=0)

# %%
data = data.reset_index(drop=True)

# %%
data
# Out:
#                           name               artist  \
# 0              No One Like You            Scorpions
# 1              Highway to Hell                AC/DC
# 2                Still Waiting               Sum 41
# 3                The Hell Song               Sum 41
# 4                  Last Resort           Papa Roach
# ...                        ...                  ...
# 1887         Hey There Delilah      Plain White T's
# 1888  I'm Not Okay (I Promise)  My Chemical Romance
# 1889  Peace Sells - Remastered             Megadeth
# 1890                 Cold Shot   Stevie Ray Vaughan
# 1891             Coming Undone              Tantric
#
#                                                   album  popularity  \
# 0                                              Blackout          64
# 1                                       Highway to Hell          81
# 2                              Does This Look Infected?          62
# ...

# %%
for i in range(0,len(data['genre'])):
  #print(i)
  data['genre'][i]= ','.join(data['genre'][i])
# Out:
# <ipython-input-254-ccf899fdd8a0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['genre'][i]= ','.join(data['genre'][i])

# %%
data
# Out:
#                           name               artist  \
# 0              No One Like You            Scorpions
# 1              Highway to Hell                AC/DC
# 2                Still Waiting               Sum 41
# 3                The Hell Song               Sum 41
# 4                  Last Resort           Papa Roach
# ...                        ...                  ...
# 1887         Hey There Delilah      Plain White T's
# 1888  I'm Not Okay (I Promise)  My Chemical Romance
# 1889  Peace Sells - Remastered             Megadeth
# 1890                 Cold Shot   Stevie Ray Vaughan
# 1891             Coming Undone              Tantric
#
#                                                   album  popularity  \
# 0                                              Blackout          64
# 1                                       Highway to Hell          81
# 2                              Does This Look Infected?          62
# ...

# %%
duplicate = data[data.duplicated()]
duplicate
# Out:
#                       name                    artist  \
# 544   Falling Away from Me                      Korn
# 546     Twisted Transistor                      Korn
# 549                Dragula                Rob Zombie
# 552    Killing In The Name  Rage Against The Machine
# 557    When Worlds Collide             Powerman 5000
# ...                    ...                       ...
# 1740  Wherever You Will Go               The Calling
# 1797            Rebel Yell                Billy Idol
# 1845            Kryptonite              3 Doors Down
# 1854                Yellow                  Coldplay
# 1866        Lying from You               Linkin Park
#
#                                                   album  popularity  \
# 544                                              Issues          70
# 546                           See You On the Other Side           0
# 549                                    Hellbilly Deluxe          73
# ...

# %%
data = data.drop_duplicates()
data
# Out:
#                           name               artist  \
# 0              No One Like You            Scorpions
# 1              Highway to Hell                AC/DC
# 2                Still Waiting               Sum 41
# 3                The Hell Song               Sum 41
# 4                  Last Resort           Papa Roach
# ...                        ...                  ...
# 1887         Hey There Delilah      Plain White T's
# 1888  I'm Not Okay (I Promise)  My Chemical Romance
# 1889  Peace Sells - Remastered             Megadeth
# 1890                 Cold Shot   Stevie Ray Vaughan
# 1891             Coming Undone              Tantric
#
#                                                   album  popularity  \
# 0                                              Blackout          64
# 1                                       Highway to Hell          81
# 2                              Does This Look Infected?          62
# ...

# %%
data = data.reset_index(drop=True)

# %%
data
# Out:
#                           name               artist  \
# 0              No One Like You            Scorpions
# 1              Highway to Hell                AC/DC
# 2                Still Waiting               Sum 41
# 3                The Hell Song               Sum 41
# 4                  Last Resort           Papa Roach
# ...                        ...                  ...
# 1808         Hey There Delilah      Plain White T's
# 1809  I'm Not Okay (I Promise)  My Chemical Romance
# 1810  Peace Sells - Remastered             Megadeth
# 1811                 Cold Shot   Stevie Ray Vaughan
# 1812             Coming Undone              Tantric
#
#                                                   album  popularity  \
# 0                                              Blackout          64
# 1                                       Highway to Hell          81
# 2                              Does This Look Infected?          62
# ...

# %%
data.to_excel('spotifydb1.xlsx')

# %%
#Creación de la playlist

# %%
"""
import json
import requests
user_id = 'diegomarlop'
endpoint_url = f"https://api.spotify.com/v1/users/{user_id}/playlists"
request_body = json.dumps({
          "name": "IronMusic",
          "description": "My first list with python",
          "public": True 
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization" :"Bearer BQDc9v3heYZTx5a_zbPViG_xKjy4ESZnju8uqDPvUJEo6xhlWzZq7YC4M3LcGpztyjB7HiTnH8b2QImzMwwDh9sJili20FNzX3EqGP70iSavEcSg4RNj6VFFstDc2NCtH_AbJLeDCd2b1MikfSLUYNKTyMj3GgUXk_jCfrVHoU2N53VJVLIz6qR5rkRRfzxmdZPycSB4raCanRVEZV7g9W9wTf9jnb5kjhlUwlkelQ"})

"""

# %%
#response.status_code

# %%
#add tracks

# %%
CLIENT_ID='6e9dc4a7a1814e978d0ca783aefdce21'
CLIENT_SECRET='901f86858e784fdeae15d4849870b786'

# %%
"""
import json
import requests
playlist_id = '5iL5tkpWdZPzQ4zV5rS5Aj'
endpoint_url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"

request_body = json.dumps({
          "uris" : uris
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer YOUR_TOKEN_HERE"})
"""

# %%
token = "BQC_mF_R01bQomOdcTuOhvXa5yPv97R0P0GKzhapis_RombdLCE3YVW4DZl3OGaZ4MEwlll4ROWmbhLmp64KYjvJnyddNLI03p-OAeui8yNIbPsO28rMxaVrRUTFxwtoDOhC-PSPuMmoCetXhx9QJbzgjocT4Cwrs0XPDzxsf_P2zey0A7deKQ9PVSYvXVnvN02SD3SyewKXQ4n_0w"

# %%
sp = spotipy.Spotify(token)

# %%
#sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri1)

# %%
"""
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri2)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri3)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri4)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri5)
"""

# %%
"""
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri6)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri7)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri8)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri9)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri10)
"""

# %%
"""
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri11)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri12)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri13)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri14)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri15)
"""

# %%
"""
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri16)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri17)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri18)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri19)
sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri20)
"""

# %%
list_uris_total = []

# %%
list_uris_total.append((list_uri1,list_uri2,list_uri3,list_uri4,list_uri5,list_uri6,list_uri7,list_uri8,list_uri9,list_uri10,list_uri11,list_uri12,list_uri13,list_uri14,list_uri15,list_uri16,list_uri17,list_uri18,list_uri19,list_uri20))

# %%
len(list_uris_total[0][11])

# %%
len(list_uri1)

# %%
demo = []

# %%
len(demo)

# %%
demo = list_uris_total[0][10]

# %%
demo

# %%
len(demo)

# %%
tracks = list(data['name'])

# %%
len(n)

# %%
def get_playlist_tracks(username,playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
#n = get_playlist_tracks('Diego_Mtz','5iL5tkpWdZPzQ4zV5rS5Aj')

# %%
"""list_uris = []
for cancion in n:
  list_uris.append(cancion['track']['uri'])"""

# %%
#list_uris

# %%
"""df = pd.DataFrame()
df['uris']=list_uris"""

# %%
#df

# %%
"""duplicated2 = df[df.duplicated()]
duplicated2"""

# %%
"""uris_duplicated = list(duplicated2['uris'])
len(uris_duplicated)"""

# %%
"""df = df.drop_duplicates().reset_index(drop=True)
df"""

# %%
#token = "BQBDrei21PWNWBakmE2RLrN6cWmzWwbwqisjk1_CPHv5mJc271n2OQtet_tJUMycc6guH5Y4hHbHJlfU6rRBUrlIR0NEbBxq3OohgsOA-5-BAGPfMq1b7YqpPHE_AZrAHVhMTgil3ka8usgrMcqjZ5Qm1iDsLPe-zPKAAd7o_n0j-MPxJ11nFojoOaWTcpvOOFhxXUHHy59Vm8Snnw"

# %%
#sp = spotipy.Spotify(token)

# %%
"""
sp.user_playlist_remove_all_occurrences_of_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=uris_duplicated)
"""

# %%
#add the songs duplicated
token = "BQC6hd0ctuikeUAPh1_E-67m8J5vXDesrg4OvYk2Q458VoECS_rzl6d8Q5_yk056zksKk8yUPVifLCXaBe4dwlD6x_fk4cZCFriZKvk-Zjs8StKAauS8u5CVLBgi3XYbvxwsjlFLvH6pW7LnDGl-7eivrrU_1_TK1sWF85deZxgsOYjLlcjZrJB06aBzAhBAjoJgJ9hqoG83n44WxQ"

# %%
#sp = spotipy.Spotify(token)

# %%
#duplicated

# %%
#sp.user_playlist_add_tracks(user='diegomarlop',playlist_id='5iL5tkpWdZPzQ4zV5rS5Aj',tracks=list_uri20)
